# %%
import pandas as pd
df=pd.read_excel('C:\\Users\dell\FSDS\datafsds\Attribute DataSet.xlsx')

# %%
df.to_csv('Attribute DataSet1.csv',index=False)

# %%
pd.read_csv('Attribute DataSet1.csv')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
import mysql.connector as con
import csv
con.connect(host='localhost',user='root',password='0000')

# %%
curspr=con.cursor()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d3c64fa096e9> in <module>
# ----> 1 curspr=con.cursor()
#
# TypeError: 'module' object is not callable

# %%
import mysql.connector as con

# %%
conn=con.connect(host='localhost',user='root',password='0000')

# %%
query='Create database Task1'

# %%
cursor=conn.cursor()

# %%
for i in cursor.fetchall():
    print(i)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-26-69a298b44695> in <module>
# ----> 1 for i in cursor.fetchall():
#       2     print(i)
#
# ~\anaconda3\Anaconda\lib\site-packages\mysql\connector\cursor_cext.py in fetchall(self)
#     504         Returns a list of tuples.
#     505         """
# --> 506         self._check_executed()
#     507         if not self._cnx.unread_result:
#     508             return []
#
# ~\anaconda3\Anaconda\lib\site-packages\mysql\connector\cursor_cext.py in _check_executed(self)
#     127         """
#     128         if self._executed is None:
# --> 129             raise errors.InterfaceError(ERR_NO_RESULT_TO_FETCH)
#     130
#     131     def _fetch_warnings(self):
#
# InterfaceError: No result set to fetch from

# %%
cursor.execute(query)

# %%
for i in cursor.fetchall():
    print(i)

# %%
import mysql.connector as connection
try:
    con=connection.connect(host='localhost',user='root',password='0000')
    print(con.is_connected())
    query='Drop database Task1;'
    
    cur=con.cursor()
    cur.execute(query)
    
except Exception as e:
    con.close()
    print(str(e))
# Out:
# True

# %%
MySql : 1. Create A table for attribute Dat Set And Dress Data Set
    2.Do a bulk load for these two table for respective dataset 
    3.read these dataset in pandas as a dataframe 
    4.Convert attribute dataset in json Format 
    5.Store this dataset into mongodb 
    6.In SQL task try to perform left join operation with attribute datset and dress dataset on DressId 
    7.Write a sql quey to find out how many unique dress we have based on Dress id 
    8. Try to find out how many dress is having recommendation 0 
    9.Try to find out a third highest most selling Dress

# %%
import pandas as pd
import mysql.connector as conn
import csv

con=conn.connect(host='localhost',user='root',password='0000',database='Task')
cursor=con.cursor()
query="Create Table Attribute_DataSet(Dress_ID int(30),Style varchar(10),Price varchar(10),Rating float(3,1),Size char(5),Season varchar(20),NeckLine varchar(20),SleeveLength varchar(10),waiseline varchar(20),Material varchar(20),FabricType varchar(20),Decoration varchar(20),Pattern_Type varchar(20),Recommendation int(10));"

cursor.execute()

# %%
data=open('Attribute DataSet1.csv','r')
next(data)
data_csv=csv.reader(data,delimiter=',')
print(data_csv)
for i in enumerate(data_csv):
    for j in i[i]:
        cursor.execute('insert into Task.Attribute_DataSet values({data})'.format(data=(j)))
print('All Data Inserted Successfully')
con.commit()
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-bace9734a096> in <module>
#       4 print(data_csv)
#       5 for i in enumerate(data_csv):
# ----> 6     for j in i[i]:
#       7         cursor.execute('insert into Task.Attribute_DataSet values({data})'.format(data=(j)))
#       8 print('All Data Inserted Successfully')
#
# TypeError: tuple indices must be integers or slices, not tuple

# %%
import mysql.connector
from mysql.connector import Error
from sqlalchemy import create_engine
import pandas as pd

# %%
host_name='localhost'
user_name='root'
user_password='0000'
db_name='Task'
port_num=3306

# %%
engine=create_engine("mysql+pymysql://root:0000@localhost/Task")

# %%
my_df=pd.read_csv('Attribute DataSet2.csv')
my_df.to_sql(name='Attribute_DataSet',con=engine,if_exists='append',index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#
# ~\anaconda3\Anaconda\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# ~\anaconda3\Anaconda\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
# ...

# %%
# !pip install pymysql

# %%
my_df['Material'].fillna(method ='ffill',inplace=True)

# %%
my_df.fillna(my_df.mean())
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
my_df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
my_df['Material'].fillna('silk',inplace=True)

# %%
my_df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           silk     chiffon     ruffles
# ...

# %%
my_df['FabricType'].fillna('Data Missing',inplace=True)

# %%
my_df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material    FabricType  Decoration  \
# 0      sleevless    empire           silk       chiffon     ruffles
# ...

# %%
#my_df['Pattern Type'].fillna('Data Missing',inplace=True)
my_df[my_df['Recommendation'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Dress_ID, Style, Price, Rating, Size, Season, NeckLine, SleeveLength, waiseline, Material, FabricType, Decoration, Pattern Type, Recommendation]
# Index: []

# %%
my_df.to_csv('Attribute DataSet2.csv',index=False)
