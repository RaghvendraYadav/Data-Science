# %%
import pandas as pd

# %%
pd.read_excel('Attribute DataSet.xlsx')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df=pd.read_excel(r'C:\\Users\dell\FSDS\datafsds\Attribute DataSet.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
type(df)# Type is DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
# Out:
#   GHb     hj
# 0     t    h
# 1    js    f
# 2     t  dgd
# 3    ht   jd
# 4   fjj  NaN

# %%
pd.read_excel(r'C:\\Users\dell\FSDS\datafsds\Attribute DataSet.xlsx',sheet_name='SS')# sheet_name
# Out:
#   GHb     hj
# 0     t    h
# 1    js    f
# 2     t  dgd
# 3    ht   jd
# 4   fjj  NaN

# %%
pd.read_excel(r'C:\\Users\dell\FSDS\datafsds\Attribute DataSet.xlsx',sheet_name='SS',header=None)# if we not want header header=None
# Out:
#        0    1
# 0  GHb     hj
# 1      t    h
# 2     js    f
# 3      t  dgd
# 4     ht   jd
# 5    fjj  NaN

# %%
pd.read_excel(r'C:\\Users\dell\FSDS\datafsds\Attribute DataSet.xlsx',sheet_name='SS',header=None,names=['A','B'])# names gives own column names
# Out:
#        A    B
# 0  GHb     hj
# 1      t    h
# 2     js    f
# 3      t  dgd
# 4     ht   jd
# 5    fjj  NaN

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.head(2)
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %% [markdown]
# ##

# %%
df.tail(3)
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 497    empire   cotton         NaN       lace        solid               1
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
pd.read_csv('C:\\Users\dell\FSDS\datafsds\haberman.csv')
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
pd.read_csv('C:\\Users\dell\FSDS\datafsds\haberman.csv',header=None)
# Out:
#       0   1  2  3
# 0    30  64  1  1
# 1    30  62  3  1
# 2    30  65  0  1
# 3    31  59  2  1
# 4    31  65  4  1
# ..   ..  .. .. ..
# 301  75  62  1  1
# 302  76  67  0  1
# 303  77  65  3  1
# 304  78  65  1  2
# 305  83  58  2  2
#
# [306 rows x 4 columns]

# %%
pd.read_csv('C:\\Users\dell\FSDS\datafsds\haberman.csv',header=None,names=['age',"Patient's year of operation",'Number of positive axillary nodes','Survival status'])
# Out:
#      age  Patient's year of operation  Number of positive axillary nodes  \
# 0     30                           64                                  1
# 1     30                           62                                  3
# 2     30                           65                                  0
# 3     31                           59                                  2
# 4     31                           65                                  4
# ..   ...                          ...                                ...
# 301   75                           62                                  1
# 302   76                           67                                  0
# 303   77                           65                                  3
# 304   78                           65                                  1
# 305   83                           58                                  2
#
#      Survival status
# 0                  1
# 1                  1
# 2                  1
# ...

# %%
pd.read_csv('C:\\Users\dell\FSDS\datafsds\haberman1.csv',header=None,names=['age',"Patient's year of operation",'Number of positive axillary nodes','Survival status'],sep='@')
# Out:
#      age  Patient's year of operation  Number of positive axillary nodes  \
# 0     30                           64                                  1
# 1     30                           62                                  3
# 2     30                           65                                  0
# 3     31                           59                                  2
# 4     31                           65                                  4
# ..   ...                          ...                                ...
# 607   75                           62                                  1
# 608   76                           67                                  0
# 609   77                           65                                  3
# 610   78                           65                                  1
# 611   83                           58                                  2
#
#      Survival status
# 0                  1
# 1                  1
# 2                  1
# ...

# %%
pd.read_csv('C:\\Users\dell\FSDS\datafsds\haberman1.csv')
# Out:
#       30@64@1@1
# 0     30@62@3@1
# 1     30@65@0@1
# 2     31@59@2@1
# 3     31@65@4@1
# 4    33@58@10@1
# ..          ...
# 606   75@62@1@1
# 607   76@67@0@1
# 608   77@65@3@1
# 609   78@65@1@2
# 610   83@58@2@2
#
# [611 rows x 1 columns]

# %%
pd.read_csv('C:\\Users\dell\FSDS\datafsds\haberman1.csv',sep='@')# Read Sepearted value by sep
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 606  75  62   1    1
# 607  76  67   0    1
# 608  77  65   3    1
# 609  78  65   1    2
# 610  83  58   2    2
#
# [611 rows x 4 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
a=pd.read_html('https://www.basketball-reference.com/playoffs/2016-nba-finals-cavaliers-vs-warriors.html')# Read Html Data

# %%
a
# Out:
# [                       0              1              2
#  0          Game 1, Jun 2  Game 1, Jun 2  Game 1, Jun 2
#  1    Cleveland Cavaliers             89          Final
#  2  Golden State Warriors            104            NaN,
#       0              1   2
#  0  PTS  K. Irving-CLE  26
#  1  TRB    K. Love-CLE  13,
#                         0              1              2
#  0          Game 2, Jun 5  Game 2, Jun 5  Game 2, Jun 5
#  1    Cleveland Cavaliers             77          Final
#  2  Golden State Warriors            110            NaN,
#       0             1   2
#  0  PTS  D. Green-GSW  28
#  1  TRB  S. Curry-GSW   9,
#                         0              1              2
#  0          Game 3, Jun 8  Game 3, Jun 8  Game 3, Jun 8
#  1  Golden State Warriors             90          Final
#  2    Cleveland Cavaliers            120            NaN,
#       0                1   2
#  0  PTS     L. James-CLE  32
#  1  TRB  T. Thompson-CLE  13,
# ...

# %%
type(a)# it will read data in List Type
# Out:
# list

# %%
len(a)
# Out:
# 14

# %%
a[0]# it will gve the fisrt table in the Html in DataFrame type
# Out:
#                        0              1              2
# 0          Game 1, Jun 2  Game 1, Jun 2  Game 1, Jun 2
# 1    Cleveland Cavaliers             89          Final
# 2  Golden State Warriors            104            NaN

# %%
# Read JSon Data
pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js=pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
js['user']
# Out:
# 0     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 1     {'login': 'shourya5', 'id': 73142986, 'node_id...
# 2     {'login': 'adrienpacifico', 'id': 6614121, 'no...
# 3     {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 4     {'login': 'attack68', 'id': 24256554, 'node_id...
# 5     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 6     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 7     {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 8     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 9     {'login': 'GivyBoy', 'id': 58392771, 'node_id'...
# 10    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 11    {'login': 'SomtochiUmeh', 'id': 74836691, 'nod...
# 12    {'login': 'adrienpacifico', 'id': 6614121, 'no...
# 13    {'login': 'Brinkhuis', 'id': 3044985, 'node_id...
# 14    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 15    {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 16    {'login': 'parthi-siva', 'id': 25401444, 'node...
# ...

# %%
df.to_json('test.json')

# %%
pd.read_json('test.json')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           None     chiffon     ruffles
# ...

# %%
pwd
# Out:
# 'C:\\Users\\dell\\FSDS'

# %%
df.to_csv('C://Users/dell/test1.csv')

# %%
df.to_csv('C://Users/dell/test1.csv',sep='@')

# %%
df.to_csv('C://Users/dell/test12.csv',index=False)

# %% [markdown]
# MySql :
#     1. Create A table for attribute Dat Set And Dress Data Set
#     2.Do a bulk load for these two table for respective dataset
#     3.read these dataset in pandas as a dataframe
#     4.Convert attribute dataset in json Format
#     5.Store this dataset into mongodb
#     6.In SQL task try to perform left join operation with attribute datset and dress dataset on DressId
#     7.Write a sql quey to find out how many unique dress we have based on Dress id
#     8. Try to find out how many dress is having recommendation 0
#     9.Try to find out a third highest most selling Dress
