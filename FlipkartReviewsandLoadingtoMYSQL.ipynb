# %%
from flask import Flask,render_template,request,jsonify
from bs4 import BeautifulSoup as  bs
from urllib.request import urlopen as urReq

# %%
flipkart_url="https://www.flipkart.com/search?q="+"iphone11"

# %%
response_website=urReq(flipkart_url)# hit the URl

# %%
data_flipkart = response_website.read()

# %%
beautify_html=bs(data_flipkart,"html.parser")

# %%
beautify_html.find_all("div",{"class":"_1AtVbE col-12-12"})
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone11&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy
# ...

# %%
bigbox=beautify_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
bigbox[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone11&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,
# ...

# %%
product6_url="https://www.flipkart.com"+bigbox[6].div.div.div.a["href"]

# %%
import requests

# %%
product6page=requests.get(product6_url)

# %%
product6page.encoding='utf-8'

# %%
product6_pagesource=bs(product6page.text,"html.parser")

# %%
all_reviews6=product6_pagesource.find_all("div",{"class":"_16PBlm"})

# %%
len(all_reviews6)
# Out:
# 11

# %%
comment_header=all_reviews6[9].div.div.p.text

# %%
name=all_reviews6[8].find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text

# %%
price=product6_pagesource.find_all("div",{"class":"_30jeq3 _16Jk6d"})[0].text

# %%
ratings=all_reviews6[5].find_all('div',{'class':"_3LWZlK _1BLPMq"})[0].text

# %%
reviews=all_reviews6[5].div.div.find_all('div',{"class":""})[0].text

# %%
try:
    for i in range(0,len(all_reviews6)-1):
        name = all_reviews6[i].find_all('p', {"class": "_2sc7ZR _2V5EHH"})[0].text
        ratings =all_reviews6[i].find_all('div',{'class':"_3LWZlK _1BLPMq"})[0].text
        comment_header = all_reviews6[i].div.div.p.text
        reviews = all_reviews6[i].div.div.find_all('div', {"class": ""})[0].text
        date =all_reviews6[i].find_all('p', {"class": "_2sc7ZR"})[1].text
        price = product6_pagesource.find_all('div', {"class": "_30jeq3 _16Jk6d"})[0].text
        import mysql.connector as conn

        mydb = conn.connect(host="localhost", user="root", password="0000")
        cursor = mydb.cursor()
        
        #print(cursor.fetchall())

        # print(name  ,rating  ,comment_header ,reviews ,date  ,price)  Table
        # query="create  table if not exists Loadscrap.reviewflipkart(name varchar(50),rating int, reviews varchar(100), date varchar(80))"
        # cursor.execute(query)
        #
        # #Insert
        #query1="insert into Loadscrap.reviewflipkart values (%s, %s,%s, %s,%s) ", (name, ratings, reviews, date)
        cursor.execute("insert into Loadscrap.ReviewsData1 values (%s, %s,%s,%s,%s) ",
                       (name, ratings, reviews,comment_header, date))
        mydb.commit()

        print(name, ratings, comment_header, reviews, date, price)
except Exception as e:
    print(e)
# Out:
# Flipkart Customer 5 Simply awesome Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.READ MORE Nov, 2020 ₹39,999
# Flipkart Customer 5 Perfect product! Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .READ MORE Jun, 2020 ₹39,999
# Manish Raghuvanshi 5 Best in the market! Great iPhone very snappy experience as apple kind. Upgraded from iPhone 7. Pros-Camera top class - Battery top performed -Chipset no need to say as apple kind -Security as you expect from apple - Display super bright industry leading colour   accuracy and super responsive -Build quality as expect from apple sturdy  premium durable beautiful stylish. -Os most stable os in smartphone industry Cons -No 5G-Display is not based on OLED technology -Charger headphones and 1 apple stic...READ MORE Apr, 2021 ₹39,999
# ...
